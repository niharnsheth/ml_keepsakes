# %%
import import_jigsaw

# %%
# importing surgical dataset

knot_tying = import_jigsaw.JigsawDataset("knot_tying")

knot_tying.labels.head()
# Out:
# task found !
#           filename self_proclaimed_skill  grs_total_score  \
# 0  Knot_Tying_B001                     N               13
# 1  Knot_Tying_B002                     N                9
# 2  Knot_Tying_B003                     N               11
# 3  Knot_Tying_B004                     N                8
# 4  Knot_Tying_C001                     I               20
#
#    grs_respect_for_tissue_score  grs_inst_handling_score  \
# 0                             2                        2
# 1                             1                        1
# 2                             1                        2
# 3                             1                        2
# 4                             4                        3
#
#    grs_time_motion_score  grs_flow_of_operation_score  grs_overall_perf_score  \
# 0                      2                            2                       2
# 1                      2                            2                       1
# ...
